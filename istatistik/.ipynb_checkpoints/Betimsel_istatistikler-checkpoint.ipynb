# %%
# Ortalama
# Medyan
# Mod
# Kartiller
# Değişim Aralığı
# Standart Sapma
# Kovaryans: iki değişken arasındaki ilişkinin değişkenlik ölçüsüdür.
# Korelasyon: iki değişken arasındaki ilişkiyi, ilişkinin anlamlı olup olmadığını, ilişkinin şiddetini ve yönünü ifade eden istatistiksel bir tekniktir.

# %% [markdown]
# # **Betimsel İstatistikler**

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
df = tips.copy()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
# !pip install researchpy
import researchpy as rp
# Out:
# Collecting researchpy
#   Downloading researchpy-0.3.5-py3-none-any.whl (33 kB)
# Requirement already satisfied: statsmodels in c:\users\acer\anaconda3\lib\site-packages (from researchpy) (0.13.2)
# Requirement already satisfied: numpy in c:\users\acer\anaconda3\lib\site-packages (from researchpy) (1.21.5)
# Requirement already satisfied: pandas in c:\users\acer\anaconda3\lib\site-packages (from researchpy) (1.4.4)
# Requirement already satisfied: scipy in c:\users\acer\anaconda3\lib\site-packages (from researchpy) (1.9.1)
# Requirement already satisfied: patsy in c:\users\acer\anaconda3\lib\site-packages (from researchpy) (0.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\acer\anaconda3\lib\site-packages (from pandas->researchpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer\anaconda3\lib\site-packages (from pandas->researchpy) (2022.1)
# Requirement already satisfied: six in c:\users\acer\anaconda3\lib\site-packages (from patsy->researchpy) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\acer\anaconda3\lib\site-packages (from statsmodels->researchpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\acer\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels->researchpy) (3.0.9)
# Installing collected packages: researchpy
# Successfully installed researchpy-0.3.5

# %%
rp.summary_cat(df[["sex","smoker","day"]])
# Out:
#   Variable Outcome  Count  Percent
# 0      sex    Male    157    64.34
# 1           Female     87    35.66
# 2   smoker      No    151    61.89
# 3              Yes     93    38.11
# 4      day     Sat     87    35.66
# 5              Sun     76    31.15
# 6             Thur     62    25.41
# 7              Fri     19     7.79

# %%
df[["tip","total_bill"]].cov() # kovaryans
# Out:
#                  tip  total_bill
# tip         1.914455    8.323502
# total_bill  8.323502   79.252939

# %%
df[["tip","total_bill"]].corr() #korelasyon
# Out:
#                  tip  total_bill
# tip         1.000000    0.675734
# total_bill  0.675734    1.000000
